# %%
pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 1.6 MB/s  0:00:05m 1.6 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 304.1 kB/s  0:00:08296.5 kB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 445.1 kB/s  0:00:118.4 kB/s eta 0:00:01:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib] 6/7 [matplotlib]ow]
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
#What does Covariance even mean?
#Co-(Variance) : When 1 things goes up, does the other thing goes up/down/don't really care. +ve covariance is more study more marks, 
#-ve covariance is high temp, low jacket sales, 0 covariance is shoe size and brain IQ.

# %%
#Lets see how a covariance matrix works!
import numpy as np
import matplotlib.pyplot as plt

#1. Random but corelated data creation
np.random.seed(22)
x = np.linspace(0, 10, 50)
y = x*2 + np.random.normal(0, 2, 50)
data = np.vstack((x,y)).T

#2. Centering the Data 
plt.scatter(data_centered[:,0], data_centered[:,1])
plt.title("Centered Data: The Starting Point")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#Eigendecomposition 

#Eigenvectors are the "Directions" of the data's spread, and Eigenvalues as the "Strength" of that spread.
#Av = λv
#We are looking for a vector v that, when multiplied by our data's covariance matrix A, doesn't change direction. It only gets scaled by λ.

#3. Calculate Covariance Matrix
cov_mat = np.cov(data_centered.T)

#4. Eigenvalues and Eigenvectors
eigenvalues, eigenvectors = np.linalg.eig(cov_mat)

print(f"Directions (Vectors):\n{eigenvectors}")
print(f"Strength (Values): {eigenvalues}")
# Out:
# Directions (Vectors):
# [[-0.90392224 -0.42769684]
#  [ 0.42769684 -0.90392224]]
# Strength (Values): [ 0.8473925 44.598134 ]

# %%
# 5. Project data onto the 1st principal component(PC)
top_eigenvector = eigenvectors[:, np.argmax(eigenvalues)]
projected_data = data_centered.dot(top_eigenvector)

# 6. Plotting the 'Flattened' 1D world
plt.figure(figsize=(8,2))
plt.scatter(projected_data, np.zeros_like(projected_data), alpha=0.5)
plt.title("2D Data compressed to 1D via PCA")
plt.show()
